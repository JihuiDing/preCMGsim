# %% [markdown]
# # This notebook explains how to create grid files for CMG simulations from a Petrel geomodel.

# %% [markdown]
# Note: this preceducre only needs to be performed once, because simulations will use the same grid files, such as corner points, null, pinchout.

# %% [markdown]
# ## Step 1: Export grid and properties from Petrel as rescue files

# %% [markdown]
# ## Step 2: Open CMG bulider, create an empty project, import resucue files, save the dat file

# %% [markdown]
# ## Step 3: Extract data from the dat file, including grid and properties.

# %% [markdown]
# ##
